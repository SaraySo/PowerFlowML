# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy import stats
from sklearn import model_selection, preprocessing, metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 


#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import LSTM, Dense

# %% [markdown]
# #### Data Import
# Import data and target to dataframes:

# %%
# import data
df = pd.read_csv(r'Data\in_data_1752.csv')
df_target = pd.read_csv(r'Data\out_data_1752.csv')

# get the data sizes
print(f'input shape:  {df.shape}')
print(f'output shape:  {df_target.shape}')
# Out:
# input shape:  (1752, 182)
# output shape:  (1752, 556)

# %% [markdown]
# Check for missing values:

# %%
# check for missing values
df.isnull().any().any()
# Out:
# False

# %% [markdown]
# #### Data cleaning

# %%
# Creating a clean data values:
df_clean = df.copy()
df_target_clean = df_target.copy()

# %% [markdown]
# Check for correlated columns:

# %%
# calculate correlation between feature columns, we take the absolute value (size of correlation)
features_corr = df_clean.corr().abs()

# refer only to the uupper triangle of the corr matrix:
upper_triangle = features_corr.where(np.triu(np.ones(features_corr.shape), k=1).astype(bool))

# drop columns above the correlation threshold
thresh = 1 # 100% correlation
drop_idx = [col for col in upper_triangle.columns if any(upper_triangle[col] >= thresh)]

# how many columns to drop?
print(f'drop: {len(drop_idx)} columns')

# drop columns
df_clean = df_clean.drop(drop_idx, axis = 1)
print(f'remaining data:  {df_clean.shape}')
# Out:
# drop: 0 columns
# remaining data:  (1752, 182)

# %% [markdown]
# Overall - no need for any cleaning of the data

# %% [markdown]
# #### Creating the Models
# We will compare LSTM to other simple DNN model.
#
# Normalization - min-max scaling

# %%
# Normalize input data
scaler = MinMaxScaler()
input_scaled = scaler.fit_transform(df_clean)
output_scaled = scaler.fit_transform(df_target_clean)

# %% [markdown]
# For DNN and LSTM:

# %%
# Define a function to create dataset for LSTM and DNN
def create_dataset(X, y, n_steps):
    Xs, ys = [], []
    for i in range(len(X) - n_steps):
        Xs.append(X[i:(i + n_steps)])
        ys.append(y[i + n_steps])
    return np.array(Xs), np.array(ys)

n_steps = 5  # Number of steps 
X, y = create_dataset(input_scaled, output_scaled, n_steps)

print(X.shape, y.shape)
# Out:
# (1747, 5, 182) (1747, 556)

# %% [markdown]
# Spliting it into 30% test and 70% training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# Reshape input for LSTM [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], df_clean.shape[1]))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], df_clean.shape[1]))

# %% [markdown]
# DNN Model:

# %%
model_dnn = tf.keras.models.Sequential([
    tf.keras.layers.Dense(50, activation='relu', input_shape=(X_train.shape[1]*X_train.shape[2],)),
    tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(df_target_clean.shape[1])  
])
model_dnn.compile(optimizer='adam', loss='mse')
# Out:
# C:\Users\saray\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Train the DNN :

# %%
# Flatten the input for DNN because it does not accept 3D data [samples, timesteps, features]
X_train_flattened = X_train.reshape((X_train.shape[0], X_train.shape[1]*X_train.shape[2]))
X_test_flattened = X_test.reshape((X_test.shape[0], X_test.shape[1]*X_test.shape[2]))

# Train the DNN model
history_dnn = model_dnn.fit(X_train_flattened, y_train, epochs=50, validation_data=(X_test_flattened, y_test))
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.3161 - val_loss: 0.1817
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1425 - val_loss: 0.1180
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0968 - val_loss: 0.0755
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0578 - val_loss: 0.0426
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0388 - val_loss: 0.0347
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0345 - val_loss: 0.0325
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0344 - val_loss: 0.0322
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0303 - val_loss: 0.0283
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0278 - val_loss: 0.0233
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0249 - val_loss: 0.0393
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0253 - val_loss: 0.0164
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0156 - val_loss: 0.0122
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0144 - val_loss: 0.0142
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0101 - val_loss: 0.0082
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0082 - val_loss: 0.0095
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0120 - val_loss: 0.0064
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 0.0089
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - val_loss: 0.0085
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - val_loss: 0.0031
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - val_loss: 0.0035
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0047 - val_loss: 0.0043
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - val_loss: 0.0059
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061 - val_loss: 0.0025
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - val_loss: 0.0024
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - val_loss: 0.0025
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - val_loss: 0.0049
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0044 - val_loss: 0.0076
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - val_loss: 0.0021

# %% [markdown]
# LSTM Model:

# %%
model_lstm = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])),
    tf.keras.layers.Dense(df_target_clean.shape[1])  
])
model_lstm.compile(optimizer='adam', loss='mse')
# Out:
# C:\Users\saray\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Train the LSTM :

# %%
history_lstm = model_lstm.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.2634 - val_loss: 0.0219
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0179 - val_loss: 0.0104
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0110 - val_loss: 0.0084
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088 - val_loss: 0.0072
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - val_loss: 0.0055
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - val_loss: 0.0039
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - val_loss: 0.0025
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - val_loss: 0.0015

# %% [markdown]
# #### Evaluate the Model
# MSE - sensitivity to outliers

# %%
mse_lstm = model_lstm.evaluate(X_test, y_test)
mse_dnn = model_dnn.evaluate(X_test_flattened, y_test)

print("MSE for LSTM:", mse_lstm)
print("MSE for DNN:", mse_dnn)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018
# MSE for LSTM: 0.0015283013926818967
# MSE for DNN: 0.0021018311381340027

# %% [markdown]
# Plot Predictions Over Time

# %%
# Predicting with models
y_pred_lstm = model_lstm.predict(X_test)
y_pred_dnn = model_dnn.predict(X_test_flattened)

# Plotting the results
plt.figure(figsize=(14, 7))

plt.subplot(1, 2, 1)
plt.plot(y_test)
plt.plot(y_pred_lstm)
plt.title('Comparison of LSTM Predictions and Actual Data')
plt.xlabel('Time Steps')
plt.ylabel('Normalized Values')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(y_test)
plt.plot(y_pred_dnn)
plt.title('Comparison of DNN Predictions and Actual Data')
plt.xlabel('Time Steps')
plt.ylabel('Normalized Values')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# XY Scatter Plot for Model Accuracy

# %%
# Scatter plot to show accuracy of predictions
plt.figure(figsize=(12, 6))

# LSTM Prediction Accuracy
plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred_lstm, alpha=0.5, color='red')
plt.plot([np.min(y_test), np.max(y_test)], [np.min(y_test), np.max(y_test)], 'k--', lw=2)  # Diagonal line
plt.title('LSTM Prediction Accuracy')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')

# DNN Prediction Accuracy
plt.subplot(1, 2, 2)
plt.scatter(y_test, y_pred_dnn, alpha=0.5, color='green')
plt.plot([np.min(y_test), np.max(y_test)], [np.min(y_test), np.max(y_test)], 'k--', lw=2)  # Diagonal line
plt.title('DNN Prediction Accuracy')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')

plt.tight_layout()
plt.show()

# %% [markdown]
# The DNN, which does not inherently consider time dependencies, performs similarly to the LSTM, which does. it might be that the time dependencies in the data are not strongly predictive of future values, or the patterns are relatively simple. meaning that the system's past values don't significantly influence future outcomes. (system might be in a steady state)
